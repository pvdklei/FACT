# %%
import score_cv2
import pandas as pd
import importlib
import load
import os

score_cv2 = importlib.reload(score_cv2)
load = importlib.reload(load)

ORIGINAL_CVS_FOLDER = "original_cvs"
MODIFIED_CVS_FOLDER = "modified_cvs"
SCORES_FOLDER = "cv_scores"

# %% [markdown]
# # Load the CV's dataset from `load.ipynb`

# %%
uiux_pm_520_df = pd.read_csv(os.path.join(ORIGINAL_CVS_FOLDER, "original_cvs.csv"), index_col=0)

# %% [markdown]
# # Load the job descriptions from the folder `job_descriptions/`

# %%
job_names_pm, job_descriptions_pm = load.get_pm_job_descriptions()
job_names_uiux, job_descriptions_uiux = load.get_uiux_job_descriptions()

all_job_names = job_names_pm + job_names_uiux
all_job_descriptions = job_descriptions_pm + job_descriptions_uiux

# %% [markdown]
# # Scores for original CVs

# %%
uiux_pm_520_just_cvs_df = uiux_pm_520_df[["CV"]]

uiux_pm_520_original_scores_df = score_cv2.score_cvs_multi_jobs_df(
    uiux_pm_520_just_cvs_df, all_job_descriptions, all_job_names, device="mps", verbose=True
)
# Out:
# Encoding 520 CVs (batch_size=64) with anass1209/resume-job-matcher-all-MiniLM-L6-v2...
# Batches: 100%|██████████| 9/9 [00:05<00:00,  1.55it/s]
# Encoding 10 job descriptions...

# %%
uiux_pm_520_original_scores_df.to_csv("uiux_pm_520_original_cvs_scores.csv")

# %% [markdown]
# # Scores of Haiku 4.5 modifed CVs

# %%
uiux_pm_520_haiku_modified_cvs_doordash_df = pd.read_csv("uiux_pm_520_haiku_modified_cvs_doordash.csv", index_col=0)
uiux_pm_520_haiku_modified_cvs_google_ux_df = pd.read_csv("uiux_pm_520_haiku_modified_cvs_google_ux.csv", index_col=0)

# %%
uiux_pm_520_haiku_modified_cv_scores_doordash_df = score_cv2.score_cvs_multi_jobs_df(
    uiux_pm_520_haiku_modified_cvs_doordash_df,
    all_job_descriptions,
    all_job_names,
    device="mps",
    verbose=True,
)
# Out:
# Encoding 520 CVs (batch_size=64) with anass1209/resume-job-matcher-all-MiniLM-L6-v2...
# Batches: 100%|██████████| 9/9 [00:07<00:00,  1.17it/s]
# Encoding 10 job descriptions...

# %%
uiux_pm_520_haiku_modified_cv_scores_doordash_df.to_csv("uiux_pm_520_haiku_modified_cv_scores_doordash.csv")

# %%
uiux_pm_520_haiku_modified_cv_scores_google_ux_df = score_cv2.score_cvs_multi_jobs_df(
    uiux_pm_520_haiku_modified_cvs_google_ux_df,
    all_job_descriptions,
    all_job_names,
    device="mps",
    verbose=True,
)
# Out:
# Encoding 520 CVs (batch_size=64) with anass1209/resume-job-matcher-all-MiniLM-L6-v2...
# Batches: 100%|██████████| 9/9 [00:05<00:00,  1.70it/s]
# Encoding 10 job descriptions...

# %%
uiux_pm_520_haiku_modified_cv_scores_google_ux_df.to_csv("uiux_pm_520_haiku_modified_cv_scores_google_ux.csv")

# %% [markdown]
# #### And twice modified

# %%
twice_modified_haiku_cvs_doordash_pm_df = pd.read_csv(os.path.join(MODIFIED_CVS_FOLDER, "twice_haiku_doordash_pm.csv"), index_col=0)
twice_modified_haiku_cvs_google_ux_df = pd.read_csv(os.path.join(MODIFIED_CVS_FOLDER, "twice_haiku_google_ux.csv"), index_col=0)

# %%
scores_twice_modified_haiku_doordash_pm_df = score_cv2.score_cvs_multi_jobs_df(
    twice_modified_haiku_cvs_doordash_pm_df,
    all_job_descriptions,
    all_job_names,
    device="mps",
    verbose=True,
)


scores_twice_modified_haiku_google_ux_df = score_cv2.score_cvs_multi_jobs_df(
    twice_modified_haiku_cvs_google_ux_df,
    all_job_descriptions,
    all_job_names,
    device="mps",
    verbose=True,
)
# Out:
# Encoding 520 CVs (batch_size=64) with anass1209/resume-job-matcher-all-MiniLM-L6-v2...
# Batches: 100%|██████████| 9/9 [00:12<00:00,  1.37s/it]
# Encoding 10 job descriptions...
# Encoding 520 CVs (batch_size=64) with anass1209/resume-job-matcher-all-MiniLM-L6-v2...
# Batches: 100%|██████████| 9/9 [00:05<00:00,  1.62it/s]
# Encoding 10 job descriptions...

# %%
scores_twice_modified_haiku_doordash_pm_df.to_csv(os.path.join(SCORES_FOLDER, "twice_haiku_doordash_pm.csv"))
scores_twice_modified_haiku_google_ux_df.to_csv(os.path.join(SCORES_FOLDER, "twice_haiku_google_ux.csv"))

# %% [markdown]
# # Sonnet 4.5 modified CV scores

# %%
uiux_pm_520_sonnet_modified_cvs_doordash_df = pd.read_csv("uiux_pm_520_sonnet_modified_cvs_doordash.csv", index_col=0)
uiux_pm_520_sonnet_modified_cvs_google_ux_df = pd.read_csv("uiux_pm_520_sonnet_modified_cvs_google_ux.csv", index_col=0)

# %%
uiux_pm_520_sonnet_modified_cv_scores_doordash_df = score_cv2.score_cvs_multi_jobs_df(
    uiux_pm_520_sonnet_modified_cvs_doordash_df,
    all_job_descriptions,
    all_job_names,
    device="mps",
    verbose=True,
)

uiux_pm_520_sonnet_modified_cv_scores_google_ux_df = score_cv2.score_cvs_multi_jobs_df(
    uiux_pm_520_sonnet_modified_cvs_google_ux_df,
    all_job_descriptions,
    all_job_names,
    device="mps",
    verbose=True,
)
# Out:
# Encoding 520 CVs (batch_size=64) with anass1209/resume-job-matcher-all-MiniLM-L6-v2...
# Batches: 100%|██████████| 9/9 [00:06<00:00,  1.47it/s]
# Encoding 10 job descriptions...
# Encoding 520 CVs (batch_size=64) with anass1209/resume-job-matcher-all-MiniLM-L6-v2...
# Batches: 100%|██████████| 9/9 [00:05<00:00,  1.61it/s]
# Encoding 10 job descriptions...

# %%
uiux_pm_520_sonnet_modified_cv_scores_doordash_df.to_csv("uiux_pm_520_sonnet_modified_cv_scores_doordash.csv")
uiux_pm_520_sonnet_modified_cv_scores_google_ux_df.to_csv("uiux_pm_520_sonnet_modified_cv_scores_google_ux.csv")

# %% [markdown]
# #### And for the twice modified

# %%
twice_modified_sonnet_cvs_doordash_pm_df = pd.read_csv(os.path.join(MODIFIED_CVS_FOLDER, "twice_sonnet_doordash_pm.csv"), index_col=0)
twice_modified_sonnet_cvs_google_ux_df = pd.read_csv(os.path.join(MODIFIED_CVS_FOLDER, "twice_sonnet_google_ux.csv"), index_col=0)

# %%
scores_twice_modified_sonnet_doordash_pm_df = score_cv2.score_cvs_multi_jobs_df(
    twice_modified_sonnet_cvs_doordash_pm_df,
    all_job_descriptions,
    all_job_names,
    device="mps",
    verbose=True,
)

scores_twice_modified_sonnet_google_ux_df = score_cv2.score_cvs_multi_jobs_df(
    twice_modified_sonnet_cvs_google_ux_df,
    all_job_descriptions,
    all_job_names,
    device="mps",
    verbose=True,
)
# Out:
# Encoding 520 CVs (batch_size=64) with anass1209/resume-job-matcher-all-MiniLM-L6-v2...
# Batches: 100%|██████████| 9/9 [00:06<00:00,  1.41it/s]
# Encoding 10 job descriptions...
# Encoding 520 CVs (batch_size=64) with anass1209/resume-job-matcher-all-MiniLM-L6-v2...
# Batches: 100%|██████████| 9/9 [00:05<00:00,  1.60it/s]
# Encoding 10 job descriptions...

# %%
scores_twice_modified_sonnet_doordash_pm_df.to_csv(os.path.join(SCORES_FOLDER, "twice_sonnet_doordash_pm.csv"))
scores_twice_modified_sonnet_google_ux_df.to_csv(os.path.join(SCORES_FOLDER, "twice_sonnet_google_ux.csv"))

# %% [markdown]
# # Scores for Opus 4.5 modified CVs

# %%
uiux_pm_520_opus_modified_cvs_doordash_df = pd.read_csv("uiux_pm_520_opus_modified_cvs_doordash.csv", index_col=0)
uiux_pm_520_opus_modified_cvs_google_ux_df = pd.read_csv("uiux_pm_520_opus_modified_cvs_google_ux.csv", index_col=0)

# %%
uiux_pm_520_opus_modified_cv_scores_doordash_df = score_cv2.score_cvs_multi_jobs_df(
    uiux_pm_520_opus_modified_cvs_doordash_df,
    all_job_descriptions,
    all_job_names,
    device="mps",
    verbose=True,
)

uiux_pm_520_opus_modified_cv_scores_google_ux_df = score_cv2.score_cvs_multi_jobs_df(
    uiux_pm_520_opus_modified_cvs_google_ux_df,
    all_job_descriptions,
    all_job_names,
    device="mps",
    verbose=True,
)
# Out:
# Encoding 520 CVs (batch_size=64) with anass1209/resume-job-matcher-all-MiniLM-L6-v2...
# ...
# Batches: 100%|██████████| 9/9 [00:06<00:00,  1.40it/s]
# Encoding 10 job descriptions...
# Encoding 520 CVs (batch_size=64) with anass1209/resume-job-matcher-all-MiniLM-L6-v2...
# Batches: 100%|██████████| 9/9 [00:05<00:00,  1.59it/s]
# Encoding 10 job descriptions...

# %%
uiux_pm_520_opus_modified_cv_scores_doordash_df.to_csv("uiux_pm_520_opus_modified_cv_scores_doordash.csv")
uiux_pm_520_opus_modified_cv_scores_google_ux_df.to_csv("uiux_pm_520_opus_modified_cv_scores_google_ux.csv")

# %% [markdown]
# #### And for the twice modified

# %%
twice_modified_cvs_opus_doordash_pm_df = pd.read_csv(os.path.join(MODIFIED_CVS_FOLDER, "twice_opus_doordash_pm.csv"), index_col=0)
twice_modified_cvs_opus_google_ux_df = pd.read_csv(os.path.join(MODIFIED_CVS_FOLDER, "twice_opus_google_ux.csv"), index_col=0)

# %%
scores_twice_modified_opus_doordash_pm_df = score_cv2.score_cvs_multi_jobs_df(
    twice_modified_cvs_opus_doordash_pm_df,
    all_job_descriptions,
    all_job_names,
    device="mps",
    verbose=True,
)

scores_twice_modified_opus_google_ux_df = score_cv2.score_cvs_multi_jobs_df(
    twice_modified_cvs_opus_google_ux_df,
    all_job_descriptions,
    all_job_names,
    device="mps",
    verbose=True,
)
# Out:
# Encoding 520 CVs (batch_size=64) with anass1209/resume-job-matcher-all-MiniLM-L6-v2...
# Batches: 100%|██████████| 9/9 [00:06<00:00,  1.45it/s]
# Encoding 10 job descriptions...
# Encoding 520 CVs (batch_size=64) with anass1209/resume-job-matcher-all-MiniLM-L6-v2...
# Batches: 100%|██████████| 9/9 [00:05<00:00,  1.63it/s]
# Encoding 10 job descriptions...

# %%
scores_twice_modified_opus_doordash_pm_df.to_csv(os.path.join(SCORES_FOLDER, "twice_opus_doordash_pm.csv"))
scores_twice_modified_opus_google_ux_df.to_csv(os.path.join(SCORES_FOLDER, "twice_opus_google_ux.csv"))

# %% [markdown]
# # Scores for Gemini Flash 3 modified CVs

# %%
modified_cvs_gemini_flash_doordash_df = pd.read_csv(os.path.join(MODIFIED_CVS_FOLDER, "gemini_flash_doordash_pm.csv"), index_col=0)
modified_cvs_gemini_flash_google_ux_df = pd.read_csv(os.path.join(MODIFIED_CVS_FOLDER, "gemini_flash_google_ux.csv"), index_col=0)

# %%
gemini_flash_scores_doordash_df = score_cv2.score_cvs_multi_jobs_df(
    modified_cvs_gemini_flash_doordash_df,
    all_job_descriptions,
    all_job_names,
    device="mps",
    verbose=True,
)

gemini_flash_scores_google_ux_df = score_cv2.score_cvs_multi_jobs_df(
    modified_cvs_gemini_flash_google_ux_df,
    all_job_descriptions,
    all_job_names,
    device="mps",
    verbose=True,
)
# Out:
# Encoding 520 CVs (batch_size=64) with anass1209/resume-job-matcher-all-MiniLM-L6-v2...
# Batches: 100%|██████████| 9/9 [00:06<00:00,  1.41it/s]
# Encoding 10 job descriptions...
# Encoding 520 CVs (batch_size=64) with anass1209/resume-job-matcher-all-MiniLM-L6-v2...
# Batches: 100%|██████████| 9/9 [00:06<00:00,  1.50it/s]
# Encoding 10 job descriptions...

# %%
gemini_flash_scores_doordash_df.to_csv(os.path.join(SCORES_FOLDER, "gemini_flash_doordash_pm.csv"))
gemini_flash_scores_google_ux_df.to_csv(os.path.join(SCORES_FOLDER, "gemini_flash_google_ux.csv"))

# %% [markdown]
# #### And for the twice modified ones

# %%
twice_modified_cvs_gemini_flash_doordash_pm_df = pd.read_csv(os.path.join(MODIFIED_CVS_FOLDER, "twice_gemini_flash_doordash_pm.csv"), index_col=0)
twice_modified_cvs_gemini_flash_google_ux_df = pd.read_csv(os.path.join(MODIFIED_CVS_FOLDER, "twice_gemini_flash_google_ux.csv"), index_col=0)

# %%
scores_twice_modified_gemini_flash_doordash_df = score_cv2.score_cvs_multi_jobs_df(
    twice_modified_cvs_gemini_flash_doordash_pm_df,
    all_job_descriptions,
    all_job_names,
    device="mps",
    verbose=True,
)
scores_twice_modified_gemini_flash_google_ux_df = score_cv2.score_cvs_multi_jobs_df(
    twice_modified_cvs_gemini_flash_google_ux_df,
    all_job_descriptions,
    all_job_names,
    device="mps",
    verbose=True,
)
# Out:
# Encoding 520 CVs (batch_size=64) with anass1209/resume-job-matcher-all-MiniLM-L6-v2...
# Batches: 100%|██████████| 9/9 [00:06<00:00,  1.31it/s]
# Encoding 10 job descriptions...
# Encoding 520 CVs (batch_size=64) with anass1209/resume-job-matcher-all-MiniLM-L6-v2...
# Batches: 100%|██████████| 9/9 [00:05<00:00,  1.58it/s]
# Encoding 10 job descriptions...

# %%
scores_twice_modified_gemini_flash_doordash_df.to_csv(os.path.join(SCORES_FOLDER, "twice_gemini_flash_doordash_pm.csv"))
scores_twice_modified_gemini_flash_google_ux_df.to_csv(os.path.join(SCORES_FOLDER, "twice_gemini_flash_google_ux.csv"))

# %% [markdown]
# # Scores for Gemini Pro 3 modified CVs

# %%
modified_cvs_gemini_pro_doordash_df = pd.read_csv(os.path.join(MODIFIED_CVS_FOLDER, "gemini_pro_doordash_pm.csv"), index_col=0)
modified_cvs_gemini_pro_google_ux_df = pd.read_csv(os.path.join(MODIFIED_CVS_FOLDER, "gemini_pro_google_ux.csv"), index_col=0)

# %%
gemini_pro_scores_doordash_df = score_cv2.score_cvs_multi_jobs_df(
    modified_cvs_gemini_pro_doordash_df,
    all_job_descriptions,
    all_job_names,
    device="mps",
    verbose=True,
)
gemini_pro_scores_google_ux_df = score_cv2.score_cvs_multi_jobs_df(
    modified_cvs_gemini_pro_google_ux_df,
    all_job_descriptions,
    all_job_names,
    device="mps",
    verbose=True,
)
# Out:
# Encoding 520 CVs (batch_size=64) with anass1209/resume-job-matcher-all-MiniLM-L6-v2...
# Batches: 100%|██████████| 9/9 [00:07<00:00,  1.26it/s]
# Encoding 10 job descriptions...
# Encoding 520 CVs (batch_size=64) with anass1209/resume-job-matcher-all-MiniLM-L6-v2...
# Batches: 100%|██████████| 9/9 [00:06<00:00,  1.49it/s]
# Encoding 10 job descriptions...

# %%
gemini_pro_scores_doordash_df.to_csv(os.path.join(SCORES_FOLDER, "gemini_pro_doordash_pm.csv"))
gemini_pro_scores_google_ux_df.to_csv(os.path.join(SCORES_FOLDER, "gemini_pro_google_ux.csv"))

# %% [markdown]
# #### And the twice modified ones

# %%
twice_modified_cvs_gemini_pro_doordash = pd.read_csv(os.path.join(MODIFIED_CVS_FOLDER, "twice_gemini_pro_doordash_pm.csv"), index_col=0)
twice_modified_cvs_gemini_pro_google_ux = pd.read_csv(os.path.join(MODIFIED_CVS_FOLDER, "twice_gemini_pro_google_ux.csv"), index_col=0)

# %%
scores_twice_modified_gemini_pro_doordash = score_cv2.score_cvs_multi_jobs_df(
    twice_modified_cvs_gemini_pro_doordash,
    all_job_descriptions,
    all_job_names,
    device="mps",
    verbose=True,
)

scores_twice_modified_gemini_pro_google_ux = score_cv2.score_cvs_multi_jobs_df(
    twice_modified_cvs_gemini_pro_google_ux,
    all_job_descriptions,
    all_job_names,
    device="mps",
    verbose=True,
)
# Out:
# Encoding 520 CVs (batch_size=64) with anass1209/resume-job-matcher-all-MiniLM-L6-v2...
# Batches: 100%|██████████| 9/9 [00:06<00:00,  1.33it/s]
# Encoding 10 job descriptions...
# Encoding 520 CVs (batch_size=64) with anass1209/resume-job-matcher-all-MiniLM-L6-v2...
# Batches: 100%|██████████| 9/9 [00:05<00:00,  1.56it/s]
# Encoding 10 job descriptions...

# %%
scores_twice_modified_gemini_pro_doordash.to_csv(os.path.join(SCORES_FOLDER, "twice_gemini_pro_doordash_pm.csv"))
scores_twice_modified_gemini_pro_google_ux.to_csv(os.path.join(SCORES_FOLDER, "twice_gemini_pro_google_ux.csv"))

# %% [markdown]
# # Scores for Haiku 4.5 + Opus 4.5 modified CVs

# %%
twice_modified_cvs_haiku_opus_doordash_pm_df = pd.read_csv(os.path.join(MODIFIED_CVS_FOLDER, "twice_haiku_opus_doordash_pm.csv"), index_col=0)
twice_modified_cvs_haiku_opus_google_ux_df = pd.read_csv(os.path.join(MODIFIED_CVS_FOLDER, "twice_haiku_opus_google_ux.csv"), index_col=0)

# %%
scores_twice_modified_haiku_opus_doordash_pm_df = score_cv2.score_cvs_multi_jobs_df(
    twice_modified_cvs_haiku_opus_doordash_pm_df,
    all_job_descriptions,
    all_job_names,
    device="mps",
    verbose=True,
)
scores_twice_modified_haiku_opus_google_ux_df = score_cv2.score_cvs_multi_jobs_df(
    twice_modified_cvs_haiku_opus_google_ux_df,
    all_job_descriptions,
    all_job_names,
    device="mps",
    verbose=True,
)
# Out:
# Encoding 520 CVs (batch_size=64) with anass1209/resume-job-matcher-all-MiniLM-L6-v2...
# Batches: 100%|██████████| 9/9 [00:06<00:00,  1.31it/s]
# Encoding 10 job descriptions...
# Encoding 520 CVs (batch_size=64) with anass1209/resume-job-matcher-all-MiniLM-L6-v2...
# Batches: 100%|██████████| 9/9 [00:05<00:00,  1.55it/s]
# Encoding 10 job descriptions...

# %%
scores_twice_modified_haiku_opus_doordash_pm_df.to_csv(os.path.join(SCORES_FOLDER, "twice_haiku_opus_doordash_pm.csv"))
scores_twice_modified_haiku_opus_google_ux_df.to_csv(os.path.join(SCORES_FOLDER, "twice_haiku_opus_google_ux.csv"))

# %% [markdown]
# # Scores for Sonnet 4.5 + Opus 4.5 modified CVs

# %%
twice_modified_cvs_sonnet_opus_doordash_pm_df = pd.read_csv(os.path.join(MODIFIED_CVS_FOLDER, "twice_sonnet_opus_doordash_pm.csv"), index_col=0)
twice_modified_cvs_sonnet_opus_google_ux_df = pd.read_csv(os.path.join(MODIFIED_CVS_FOLDER, "twice_sonnet_opus_google_ux.csv"), index_col=0)

# %%
scores_twice_modified_sonnet_opus_doordash_pm_df = score_cv2.score_cvs_multi_jobs_df(
    twice_modified_cvs_sonnet_opus_doordash_pm_df,
    all_job_descriptions,
    all_job_names,
    device="mps",
    verbose=True,
)
scores_twice_modified_sonnet_opus_google_ux_df = score_cv2.score_cvs_multi_jobs_df(
    twice_modified_cvs_sonnet_opus_google_ux_df,
    all_job_descriptions,
    all_job_names,
    device="mps",
    verbose=True,
)
# Out:
# Encoding 520 CVs (batch_size=64) with anass1209/resume-job-matcher-all-MiniLM-L6-v2...
# Batches: 100%|██████████| 9/9 [00:07<00:00,  1.27it/s]
# Encoding 10 job descriptions...
# Encoding 520 CVs (batch_size=64) with anass1209/resume-job-matcher-all-MiniLM-L6-v2...
# Batches: 100%|██████████| 9/9 [00:05<00:00,  1.56it/s]
# Encoding 10 job descriptions...

# %%
scores_twice_modified_sonnet_opus_doordash_pm_df.to_csv(os.path.join(SCORES_FOLDER, "twice_sonnet_opus_doordash_pm.csv"))
scores_twice_modified_sonnet_opus_google_ux_df.to_csv(os.path.join(SCORES_FOLDER, "twice_sonnet_opus_google_ux.csv"))

# %% [markdown]
# # Scores for Gemini Flash 3 + Gemini Pro 3 modified CVs

# %%
twice_modified_cvs_gemini_flash_and_pro_doordash_pm_df = pd.read_csv(os.path.join(MODIFIED_CVS_FOLDER, "twice_gemini_flash_pro_doordash_pm.csv"), index_col=0)
twice_modified_cvs_gemini_flash_and_pro_google_ux_df = pd.read_csv(os.path.join(MODIFIED_CVS_FOLDER, "twice_gemini_flash_pro_google_ux.csv"), index_col=0)

# %%
scores_twice_modified_flash_pro_doordash_pm_df = score_cv2.score_cvs_multi_jobs_df(
    twice_modified_cvs_gemini_flash_and_pro_doordash_pm_df,
    all_job_descriptions,
    all_job_names,
    device="mps",
    verbose=True,
)
scores_twice_modified_flash_pro_google_ux_df = score_cv2.score_cvs_multi_jobs_df(
    twice_modified_cvs_gemini_flash_and_pro_google_ux_df,
    all_job_descriptions,
    all_job_names,
    device="mps",
    verbose=True,
)
# Out:
# Encoding 520 CVs (batch_size=64) with anass1209/resume-job-matcher-all-MiniLM-L6-v2...
# Batches: 100%|██████████| 9/9 [00:06<00:00,  1.34it/s]
# Encoding 10 job descriptions...
# Encoding 520 CVs (batch_size=64) with anass1209/resume-job-matcher-all-MiniLM-L6-v2...
# Batches: 100%|██████████| 9/9 [00:05<00:00,  1.63it/s]
# Encoding 10 job descriptions...

# %%
scores_twice_modified_flash_pro_doordash_pm_df.to_csv(os.path.join(SCORES_FOLDER, "twice_gemini_flash_pro_doordash_pm.csv"))
scores_twice_modified_flash_pro_google_ux_df.to_csv(os.path.join(SCORES_FOLDER, "twice_gemini_flash_pro_google_ux.csv"))

# %% [markdown]
# # Scores Gemini 2 Flash Lite Once modified

# %%
once_modified_flash_lite_doordash_df = pd.read_csv(os.path.join(MODIFIED_CVS_FOLDER, "gemini_flash_lite_doordash_pm.csv"), index_col=0)
once_modified_flash_lite_google_ux_df = pd.read_csv(os.path.join(MODIFIED_CVS_FOLDER, "gemini_flash_lite_google_ux.csv"), index_col=0)

# %%
scores_once_modified_flash_lite_doordash_df = score_cv2.score_cvs_multi_jobs_df(
    cv_s_dataframe=once_modified_flash_lite_doordash_df,
    job_descriptions=all_job_descriptions,
    job_names=all_job_names,
    device="mps",
    verbose=True,
)

scores_once_modified_flash_lite_google_ux_df = score_cv2.score_cvs_multi_jobs_df(
    cv_s_dataframe=once_modified_flash_lite_google_ux_df,
    job_descriptions=all_job_descriptions,
    job_names=all_job_names,
    device="mps",
    verbose=True,
)
# Out:
# Encoding 520 CVs (batch_size=64) with anass1209/resume-job-matcher-all-MiniLM-L6-v2...
# Batches: 100%|██████████| 9/9 [00:07<00:00,  1.26it/s]
# Encoding 10 job descriptions...
# Encoding 520 CVs (batch_size=64) with anass1209/resume-job-matcher-all-MiniLM-L6-v2...
# Batches: 100%|██████████| 9/9 [00:05<00:00,  1.53it/s]
# Encoding 10 job descriptions...

# %%
scores_once_modified_flash_lite_doordash_df.to_csv(os.path.join(SCORES_FOLDER, "gemini_flash_lite_doordash_pm.csv"))
scores_once_modified_flash_lite_google_ux_df.to_csv(os.path.join(SCORES_FOLDER, "gemini_flash_lite_google_ux.csv"))

# %% [markdown]
# # Scores for twice modified by Gemini Flash Lite CVs

# %%
twice_modified_gemini_flash_lite_doordash_df = pd.read_csv(os.path.join(MODIFIED_CVS_FOLDER, "twice_gemini_flash_lite_doordash_pm.csv"), index_col=0)
twice_modified_gemini_flash_lite_google_ux_df = pd.read_csv(os.path.join(MODIFIED_CVS_FOLDER, "twice_gemini_flash_lite_google_ux.csv"), index_col=0)

# %%
scores_twice_modified_flash_lite_doordash_df = score_cv2.score_cvs_multi_jobs_df(
    cv_s_dataframe=twice_modified_gemini_flash_lite_doordash_df,
    job_descriptions=all_job_descriptions,
    job_names=all_job_names,
    device="mps",
    verbose=True,
)

scores_twice_modified_flash_lite_google_ux_df = score_cv2.score_cvs_multi_jobs_df(
    cv_s_dataframe=twice_modified_gemini_flash_lite_google_ux_df,
    job_descriptions=all_job_descriptions,
    job_names=all_job_names,
    device="mps",
    verbose=True,
)
# Out:
# Encoding 520 CVs (batch_size=64) with anass1209/resume-job-matcher-all-MiniLM-L6-v2...
# Batches: 100%|██████████| 9/9 [00:06<00:00,  1.37it/s]
# Encoding 10 job descriptions...
# Encoding 520 CVs (batch_size=64) with anass1209/resume-job-matcher-all-MiniLM-L6-v2...
# Batches: 100%|██████████| 9/9 [00:05<00:00,  1.62it/s]
# Encoding 10 job descriptions...

# %%
scores_twice_modified_flash_lite_doordash_df.to_csv(os.path.join(SCORES_FOLDER, "twice_gemini_flash_lite_doordash_pm.csv"))
scores_twice_modified_flash_lite_google_ux_df.to_csv(os.path.join(SCORES_FOLDER, "twice_gemini_flash_lite_google_ux.csv"))

# %% [markdown]
# # Scores for twice modified, first by Gemini Flash Lite, then by Gemini Pro 3

# %%
twice_modified_cvs_flash_lite_pro_doordash = pd.read_csv(
    os.path.join(MODIFIED_CVS_FOLDER, "twice_gemini_flash_lite_pro_doordash_pm.csv"), index_col=0
)
twice_modified_cvs_flash_lite_pro_google_ux = pd.read_csv(
    os.path.join(MODIFIED_CVS_FOLDER, "twice_gemini_flash_lite_pro_google_ux.csv"), index_col=0
)

# %%
scores_twice_modified_flash_lite_pro_doordash = score_cv2.score_cvs_multi_jobs_df(
    cv_s_dataframe=twice_modified_cvs_flash_lite_pro_doordash,
    job_descriptions=all_job_descriptions,
    job_names=all_job_names,
    device="mps",
    verbose=True,
)

scores_twice_modified_flash_lite_pro_google_ux = score_cv2.score_cvs_multi_jobs_df(
    cv_s_dataframe=twice_modified_cvs_flash_lite_pro_google_ux,
    job_descriptions=all_job_descriptions,
    job_names=all_job_names,
    device="mps",
    verbose=True,
)
# Out:
# Encoding 520 CVs (batch_size=64) with anass1209/resume-job-matcher-all-MiniLM-L6-v2...
# Batches: 100%|██████████| 9/9 [00:16<00:00,  1.87s/it]
# Encoding 10 job descriptions...
# Encoding 520 CVs (batch_size=64) with anass1209/resume-job-matcher-all-MiniLM-L6-v2...
# Batches: 100%|██████████| 9/9 [00:08<00:00,  1.04it/s]
# Encoding 10 job descriptions...

# %%
scores_twice_modified_flash_lite_pro_doordash.to_csv(os.path.join(SCORES_FOLDER, "twice_gemini_flash_lite_pro_doordash_pm.csv"))
scores_twice_modified_flash_lite_pro_google_ux.to_csv(os.path.join(SCORES_FOLDER, "twice_gemini_flash_lite_pro_google_ux.csv"))

# %% [markdown]
# # We can also just score all at once.

# %%
score_cv2.score_all(
    cv_folder_path=MODIFIED_CVS_FOLDER,
    score_folder_path=SCORES_FOLDER,
    job_descriptions=all_job_descriptions,
    job_names=all_job_names,
    dry_run=False,
    verbose=True,
    scorer="resume-job-matcher-all-MiniLM-L6-v2",
)
# Out:
# Scoring 6 files...
# Scoring file 1/6: fourth_opus_doordash_pm.csv
# Encoding 520 CVs (batch_size=64) with anass1209/resume-job-matcher-all-MiniLM-L6-v2...
# Batches: 100%|██████████| 9/9 [00:15<00:00,  1.67s/it]
# Encoding 10 job descriptions...
# Scoring file 2/6: fourth_sonnet_google_ux.csv
# Encoding 520 CVs (batch_size=64) with anass1209/resume-job-matcher-all-MiniLM-L6-v2...
# Batches: 100%|██████████| 9/9 [00:05<00:00,  1.61it/s]
# Encoding 10 job descriptions...
# Scoring file 3/6: fourth_opus_google_ux.csv
# Encoding 520 CVs (batch_size=64) with anass1209/resume-job-matcher-all-MiniLM-L6-v2...
# Batches: 100%|██████████| 9/9 [00:05<00:00,  1.59it/s]
# Encoding 10 job descriptions...
# Scoring file 4/6: fourth_haiku_doordash_pm.csv
# Encoding 520 CVs (batch_size=64) with anass1209/resume-job-matcher-all-MiniLM-L6-v2...
# Batches: 100%|██████████| 9/9 [00:05<00:00,  1.60it/s]
# Encoding 10 job descriptions...
# Scoring file 5/6: fourth_sonnet_doordash_pm.csv
# ...

# %% [markdown]
# ### And for the old models by Nicky

# %%
score_cv2.score_all(
    cv_folder_path=os.path.join(os.path.pardir, "Nicky", "Merged_modify"),
    score_folder_path=os.path.join(os.path.pardir, "Nicky", "Scores_New_Model"),
    job_descriptions=all_job_descriptions,
    job_names=all_job_names,
    dry_run=False,
    verbose=True,
    scorer="resume-job-matcher-all-MiniLM-L6-v2",
)
# Out:
# Scoring 21 files...
# Scoring file 1/21: merged_DS1.csv
# Encoding 520 CVs (batch_size=64) with anass1209/resume-job-matcher-all-MiniLM-L6-v2...
# Batches: 100%|██████████| 9/9 [00:05<00:00,  1.67it/s]
# Encoding 10 job descriptions...
# Scoring file 2/21: merged_Mixtral1.csv
# Encoding 520 CVs (batch_size=64) with anass1209/resume-job-matcher-all-MiniLM-L6-v2...
# Batches: 100%|██████████| 9/9 [00:05<00:00,  1.79it/s]
# Encoding 10 job descriptions...
# Scoring file 3/21: merged_DS2.csv
# Encoding 520 CVs (batch_size=64) with anass1209/resume-job-matcher-all-MiniLM-L6-v2...
# Batches: 100%|██████████| 9/9 [00:05<00:00,  1.67it/s]
# Encoding 10 job descriptions...
# Scoring file 4/21: merged_Mixtral3.csv
# Encoding 520 CVs (batch_size=64) with anass1209/resume-job-matcher-all-MiniLM-L6-v2...
# Batches: 100%|██████████| 9/9 [00:05<00:00,  1.74it/s]
# Encoding 10 job descriptions...
# Scoring file 5/21: merged_Mixtral2.csv
# ...
